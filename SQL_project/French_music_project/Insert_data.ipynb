-- %% [markdown]
-- Insert values into the Album table

-- %%
INSERT INTO Album
VALUES
(1,'Feu',1),
(2,'Cyborg',1),
(3,'Les étoiles vagabondes',1),
(4,'Stamina',2),
(5,'Imani',2),
(6,'Trinity',3),
(7,'L Étrange Histoire de Mr. Anderson',3),
(8,'Timeless',4),
(9,'Transsiberian',4),
(10,'Dancehall',5),
(11,'Lamomali',6),
(12,'Qui de nous deux ?',6);

-- %% [markdown]
-- Insert values into the Album sales per year table

-- %%
INSERT INTO [Album sales per year]
VALUES
(1,2015,300000),
(1,2016,200000),
(1,2017,80000),
(1,2018,50000),
(1,2019,43000),
(1,2020,35000),
(1,2021,100000),
(2,2016,200034),
(2,2017,80067),
(2,2018,50067),
(2,2019,43543),
(2,2020,35564),
(2,2021,28000),
(3,2019,200000),
(3,2020,100000),
(3,2021,48000),
(4,2020,132000),
(4,2021,45000),
(5,2018,72000),
(5,2019,34000),
(5,2020,22000),
(5,2021,14300),
(6,2020,150000),
(6,2021,80000),
(7,2021,200000),
(8,2020,98000),
(8,2021,70080),
(9,2015,140000),
(9,2016,145000),
(9,2017,80400),
(9,2018,73240),
(9,2019,65000),
(9,2020,45000),
(9,2021,20000),
(10,2018,125000),
(10,2019,98999),
(10,2020,56780),
(10,2021,43000),
(11,2017,74000),
(11,2018,45900),
(11,2019,34000),
(11,2020,23450),
(11,2021,12340),
(12,2002,230000),
(12,2003,100000),
(12,2004,34000),
(12,2005,23000),
(12,2006,11000),
(12,2007,10000),
(12,2008,65438),
(12,2009,45600),
(12,2010,33000),
(12,2011,24000),
(12,2012,12000),
(12,2013,21000),
(12,2014,23000),
(12,2015,12000),
(12,2016,6000),
(12,2017,3000),
(12,2018,1200),
(12,2019,1000),
(12,2020,870),
(12,2021,450);

-- %% [markdown]
-- Insert data into the Artist table

-- %%
INSERT INTO Artist
VALUES
(1,'Nekfeu'),
(2,'Dinos'),
(3,'Laylow'),
(4,'Thylacine'),
(5,'The Blaze'),
(6,'M');

-- %% [markdown]
-- Insert data into Genres tables

-- %%
INSERT INTO Genres
VALUES
(1,'Rap'),
(2,'Techno'),
(3,'Pop'),
(4,'African Music'),
(5,'Rock');

-- %% [markdown]
-- Insert data into the Tracks table

-- %%
INSERT INTO Tracks
VALUES
(1,1,'Martin Eden',1),
(1,2,'Mon âme (featuring Sneazzy)',1),
(1,3,'Le horla',1),
(1,4,'Nique les clones, Pt. II',1),
(1,5,'Rêve d avoir des rêves',1),
(1,6,'Tempête',1),
(1,7,'Égérie',1),
(1,8,'Reuf (featuring Ed Sheeran)',3),
(1,9,'La moue des morts (featuring $-Crew)',1),
(1,10,'Laisse aller',1),
(1,11,'On verra',3),
(1,12,'Ma dope (featuring S.Pri Noir)',1),
(1,13,'Jeux d ombres (featuring Doums et Amber-Simone)',1),
(1,14,'Elle en avait envie',1),
(1,15,'Princesse (featuring Némir)',1),
(1,16,'Risibles amours/Des astres',1),
(1,17,'Point d interrogation (featuring Alpha Wann)',1),
(1,18,'Être humain (featuring Amber-Simone)',1),
(2,1,'Humanoïde',1),
(2,2,'Mauvaise graine',1),
(2,3,'Squa',1),
(2,4,'Réalité augmentée',1),
(2,5,'Avant tu riais (featuring Clara Luciani)',1),
(2,6,'Esquimaux (featuring Nepal)',1),
(2,7,'O.D (featuring Murkage Dave)',1),
(2,8,'Vinyle (featuring Alpha Wann)',1),
(2,9,'Saturne (featuring Sneazzy & S.Pri Noir)',1),
(2,10,'Galatée',1),
(2,11,'Le regard des gens (featuring Némir, 2zer Washington, Mekra and Doums)',1),
(2,12,'Programmé',1),
(2,13,'Besoin de sens (featuring Framal & Jazzy Bazz)',1),
(2,14,'Nekketsu (featuring Crystal Kay)',1),
(3,1,'Les étoiles vagabondes',1),
(3,2,'Alunissons',1),
(3,3,'Cheum',1),
(3,4,'Takotsubo',1),
(3,5,'Menteur menteur',1),
(3,6,'Ciel noir',1),
(3,7,'De mon mieux',1),
(3,8,'Le bruit qui court',1),
(3,9,'Elle pleut (featuring Nemir)',1),
(3,10,'Dans l univers (featuring Vanessa Paradis)',1),
(3,11,'Premier pas',1),
(3,12,'Tricheur (featuring Damso)',1),
(3,13,'Voyage léger',1),
(3,14,'Compte les hommes (featuring Alpha Wann)',1),
(3,15,'Koala mouillé',1),
(3,16,'Pixels (featuring Crystal Kay)',1),
(3,17,'1er rôle',1),
(4,1,'Diptyque',1),
(4,2,'Moins un',1),
(4,3,'Paranoïaque',1),
(4,4,'Maman m aime',1),
(4,5,'Prends soin de toi',1),
(4,6,'Je wanda',1),
(4,7,' Césaire',1),
(4,8,'Demain n existe plus',1),
(4,9,'Le Nord se souvient',1),
(4,10,'Corbillard',1),
(4,11,'Judas',1),
(4,12,'Ciel pleure feat. Laylow',1),
(4,13,'93 mesures',1),
(5,1,'Iceberg Slim',1),
(5,2,'Argentique',1),
(5,3,'Beuh et liqueurs (feat. Ateyaba)',1),
(5,4,'Hiver 2004',1),
(5,5,'Spleen',1),
(5,6,'Havana & Malibu',1),
(5,7,'Rue sans nom',1),
(5,8,'Flashé',1),
(5,9,'Helsinki',1),
(5,10,'Quelqu un de mieux',1),
(5,11,'Bloody Mary (feat. Youssoupha)',1),
(5,12,'Les pleurs du mal',1),
(5,13,'Magenta',1),
(5,14,'Donne moi un peu de temps',1),
(5,15,'Notifications',1),
(5,16,'Sophistiqué',1),
(5,17,'Presque célèbre',1),
(6,1,'Initialisation',1),
(6,2,'MEGATRON',1),
(6,3,'DEHORS DANS LA NIGHT',1),
(6,4,'HILLZ (feat. S.Pri Noir)',1),
(6,5,'PLUG (feat. Jok Air)',1),
(6,6,'Menu principal',1),
(6,7,'PIRANHA BABY',1),
(6,8,'TRINITYVILLE',1),
(6,9,'Mieux vaut pas regarder, Pt. 1',1),
(6,10,'VAMONOS (feat. Alpha Wann)',1),
(6,11,'AKANIZER',1),
(6,12,'BURNING MAN (feat. Lomepal)',1),
(6,13,'Il était une fois sous l eau',1),
(6,14,'LONGUE VIE...',1),
(6,15,'Mieux vaut pas regarder, Pt. 2',1),
(6,16,'... DE BATARD (feat. Wit.)',1),
(6,17,'Tentative de reconnexion',1),
(6,18,'POIZON',1),
(6,19,'NAKRé',1),
(6,20,'MILLION FLOWERZ',1),
(6,21,'Manuel d utilisation',1),
(6,22,'LOGICIEL TRISTE',1),
(7,1,'Un rêve étrange',1),
(7,2,'Bonsoir mon vieil ami',1),
(7,3,'Iverson',1),
(7,4,'Window Shopper Part 1',1),
(7,5,'Tu veux déjà me dire au revoir ?',1),
(7,6,'R9R-Line (feat. Damso)',1),
(7,7,'Ça va pas être possible...',1),
(7,8,'Window Shopper Part 2 (feat. Hamza)',1),
(7,9,'Stuntmen (feat. Wit. et Alpha Wann)',1),
(7,10,'NightShop BlaBla',1),
(7,11,'Voir le monde brûler',1),
(7,12,'Que la pluie',1),
(7,13,'+ de pluie...',1),
(7,14,'Spécial (feat. Fousheé et Nekfeu)',1),
(7,15,'Lost Forest',1),
(7,16,'C est eux contre nous',1),
(7,17,'Help!!!',1),
(7,18,'Tu comprends maintenant ?',1),
(7,19,'Fallen Angels (feat. slowthai)',1),
(7,20,'Une histoire étrange',1),
(8,1,'Sheremetiev',2),
(8,2,'Satie 1',2),
(8,3,'Beethoven',2),
(8,4,'Satie 2',2),
(8,5,'Mozart',2),
(8,6,'Fauré',2),
(8,7,'Schubert',2),
(8,8,'Debussy',2),
(8,9,'Interlude',2),
(8,10,'Allegri',2),
(8,11,'Verdi',2),
(9,1,'Train',2),
(9,2,'Belobezvodnoe',2),
(9,3,'Aïkhaï & Mandukhaï (interlude)',2),
(9,4,'Moskva',2),
(9,5,'Poly',2),
(9,6,'Piany Pianino',2),
(9,7,'Chaman',2),
(9,8,'Irkutsk',2),
(9,9,'Memories',2),
(10,1,'Opening',2),
(10,2,'Heaven',2),
(10,3,'SHE',2),
(10,4,'Places',2),
(10,5,'Rise',2),
(10,6,'Runaway',2),
(10,7,'Breath',2),
(10,8,'Queens',2),
(10,9,'Mount',2),
(11,1,'Manitoumani (featuring Fatoumata Diawara)',3),
(11,2,'Bal de Bamako (featuring Fatoumata Diawara & Oxmo Puccino)',3),
(11,3,'Cet air (featuring Fatoumata Diawara)',3),
(11,4,'Interlude',3),
(11,5,'Une âme (featuring Fatoumata Diawara)',3),
(11,6,'Le Bonheur (featuring Kerfala Kanté & Philippe Jaroussky)',4),
(11,7,'Solidarité (featuring Santigold, Hiba Tawaji, Ibrahim Maalouf)',4),
(11,8,'Toi moi (featuring Fatoumata Diawara & Louis Chedid)',4),
(11,9,'L Âme au Mali (featuring Amadou et Mariam & Jain)',4),
(11,10,'Mama (featuring Mamani Keïta & Moriba Diabaté)',4),
(12,1,'Mon ego',5),
(12,2,'La Bonne Étoile',5),
(12,3,'Sous ta peau',5),
(12,4,'À tes souhaits',5),
(12,5,'Qui de nous deux ?',5),
(12,6,'Ma mélodie',5),
(12,7,'Quand je vais chez elle',5),
(12,8,'La Corde sensible',5),
(12,9,'Je me démasque',5),
(12,10,'C est pas ta faute',5),
(12,11,'Gimmick',5),
(12,12,'Le Radeau',5),
(12,13,'Psyko bug',5),
(12,14,'Peau de fleur',5),
(12,15,'Ton écho',5);
